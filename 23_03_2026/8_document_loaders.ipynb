# %% [markdown]
# ### Document Loaders

# %% [markdown]
# - Load data from:
#   - PDFs
#   - Websites
#   - Databases

# %% [markdown]
# ```python
# from langchain.document_loaders import PyPDFLoader

# %% [markdown]
# - RAG (Retrieval-Augmented Generation)

# %% [markdown]
# - In LangChain, Document Loaders are used to:
# - Load data from external sources and convert it into a standard “Document” format

# %% [markdown]
# - LLMs can’t directly read files or databases.
# - So we need:
# - PDF / CSV / Website / DB → Document Loader → LangChain Document → LLM

# %% [markdown]
# - What is a “Document”?
# ```python
# Document(
#     page_content="Actual text",
#     metadata={"source": "file.pdf"}
# )
# ```

# %% [markdown]
# ___

# %% [markdown]
# - Load a text file

# %% [markdown]
# ```python
# from langchain.document_loaders import TextLoader
#
# loader = TextLoader("data.txt")
# docs = loader.load()
#
# print(docs[0].page_content)

# %% [markdown]
# ____

# %% [markdown]
# ### Types of Document Loaders (Important)

# %% [markdown]
# 1. TextLoader
# ```python
# TextLoader("file.txt")

# %% [markdown]
# 2. PyPDFLoader

# %% [markdown]
# ```python
# from langchain.document_loaders import PyPDFLoader
#
# loader = PyPDFLoader("file.pdf")
# docs = loader.load()

# %% [markdown]
# 3. WebBaseLoader

# %% [markdown]
# - Load from websites
# ```python
# from langchain.document_loaders import WebBaseLoader
#
# loader = WebBaseLoader("https://example.com")
# docs = loader.load()

# %% [markdown]
# 4. CSVLoader
# ```python
# from langchain.document_loaders import CSVLoader
#
# loader = CSVLoader(file_path="data.csv")
# docs = loader.load()

# %% [markdown]
# 5. DirectoryLoader
# - Load multiple files
# ```python
# from langchain.document_loaders import DirectoryLoader
#
# loader = DirectoryLoader("data/")
# docs = loader.load()

# %% [markdown]
# 6. Unstructured Loaders (VERY POWERFUL)

# %% [markdown]
# - Handles messy formats (PDF, HTML, DOCX)
# ```python
# from langchain.document_loaders import UnstructuredFileLoader
