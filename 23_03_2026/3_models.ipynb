# %% [markdown]
# ```python
# from lanchain_openai import ChatOpenAI
# llm=ChatOpenAI(model="gpt-4o-mini")
# ```

# %% [markdown]
# ____

# %% [markdown]
# - LLM = provider (OpenAI, Anthropic, etc.) + model name

# %% [markdown]
# #### 1. OpenAI Models
#   - Chat / General Purpose
#      - gpt-4o
#      - gpt-4o-mini
#   - Reasoning-focused
#      - o1
#      - o3-mini
#   - Embedding models
#      - text-embedding-3-large
#      - text-embedding-3-small

# %% [markdown]
# #### 2. Other Providers

# %% [markdown]
# - Anthropic (Claude)
#    - `from langchain_anthropic import ChatAnthropic`
#       - claude-3-opus
#       - claude-3-sonnet
#       - claude-3-haiku
# - Google (Gemini)
#    - `from langchain_google_genai import ChatGoogleGenerativeAI`
#       - gemini-1.5-pro
#       - gemini-1.5-flash

# %% [markdown]
# ### Open-source (Hugging Face / local)
# ```python
# from langchain_community.llms import HuggingFacePipeline

# %% [markdown]
# ___

# %% [markdown]
# #### Types of Models in LangChain

# %% [markdown]
# - Chat Models
# - LLM (completion models)
# - Embedding Models
