# %% [markdown]
# ### Text Splitters

# %% [markdown]
# - Break large data into chunks

# %% [markdown]
# ```python
# from langchain.text_splitter import RecursiveCharacterTextSplitter

# %% [markdown]
# ____

# %% [markdown]
# ```python
# from langchain.text_splitter import CharacterTextSplitter
#
# splitter = CharacterTextSplitter(
#     chunk_size=1000,
#     chunk_overlap=200
# )
#
# chunks = splitter.split_documents(docs)

# %% [markdown]
# ___

# %% [markdown]
# ### Key Parameters

# %% [markdown]
# - chunk_size (Size of each chunk =1000)
# - chunk_overlap=200

# %% [markdown]
# ___

# %% [markdown]
# ### Types of Text Splitters

# %% [markdown]
# 1. CharacterTextSplitter (Basic)
#     -  Splits by characters
#     -  Simple but not smart
# 2. RecursiveCharacterTextSplitter
#    - Best default choice

# %% [markdown]
# ```python
# from langchain.text_splitter import RecursiveCharacterTextSplitter
#
# splitter = RecursiveCharacterTextSplitter(
#     chunk_size=1000,
#     chunk_overlap=200
# )

# %% [markdown]
# ____

# %% [markdown]
# 3. TokenTextSplitter

# %% [markdown]
# - Splits based on tokens (more accurate for LLMs)
# ```python
# from langchain.text_splitter import TokenTextSplitter

# %% [markdown]
# ____

# %% [markdown]
# 4. MarkdownHeaderTextSplitter
# - For structured markdown docs

# %% [markdown]
# 5. CodeTextSplitter
#
# -  For code files (Python, JS, etc.)

# %% [markdown]
# ```python
# from langchain.document_loaders import PyPDFLoader
# from langchain.text_splitter import RecursiveCharacterTextSplitter
#
# # Load
# loader = PyPDFLoader("file.pdf")
# docs = loader.load()
#
# # Split
# splitter = RecursiveCharacterTextSplitter(
#     chunk_size=1000,
#     chunk_overlap=200
# )
#
# chunks = splitter.split_documents(docs)
#
# print(chunks[0].page_content)
